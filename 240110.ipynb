# %% [markdown]
# <a href="https://colab.research.google.com/github/furpurr/aipython/blob/main/240110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.DataFrame([['Kim', 27, 92],
                  ['Lee', 33, 98],
                  ['Park', 19, 87]])


print(df1)
df1 # print(df1) 한거랑 무슨 차이일까

df2 = pd.DataFrame({'name': ['Kim', 'Lee', 'Park'],
                    'age': [27, 33, 19],
                    'score': [92, 98, 87]})
# 왜 df2는 중괄호? -> 딕셔너리 !!!!!!
print(df2)
df2
# Out:
#       0   1   2
# 0   Kim  27  92
# 1   Lee  33  98
# 2  Park  19  87
#    name  age  score
# 0   Kim   27     92
# 1   Lee   33     98
# 2  Park   19     87
#    name  age  score
# 0   Kim   27     92
# 1   Lee   33     98
# 2  Park   19     87

# %%
df = pd.read_csv('data.csv', encoding='UTF-8')



print(df)


df # 좀더 pandas의 기능이 들어있는 출력이 되어버렸다.
# Out:
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv', delimiter='\t', encoding='UTF-8')
print(df)
df
print(df.shape)
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df.head(3)
# Out:
#     반   이름 성별    국어    수학 응시여부 확인여부
# 0  A반  구이서  남  90.0  89.0   응시   확인
# 1  B반  김이정  여  78.0  45.0   응시   확인
# 2  A반  오지수  남   NaN   NaN   응시   확인

# %%
df.info() # object는 대부분 str, non-null은 비지 않은 값을 나타내는거(비결측치)(전체 데이터에서 이걸 빼면 결측치를 알수 있음)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   반       10 non-null     object
#  1   이름      10 non-null     object
#  2   성별      10 non-null     object
#  3   국어      7 non-null      float64
#  4   수학      7 non-null      float64
#  5   응시여부    8 non-null      object
#  6   확인여부    7 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 688.0+ bytes

# %%
print(df['이름']) # 'df['이름']은 df.이름'과 같음
# Out:
# 0    구이서
# 1    김이정
# 2    오지수
# 3    김선후
# 4    하진희
# 5    강현진
# 6    김진솔
# 7    박서준
# 8    김성희
# 9    이지서
# Name: 이름, dtype: object

# %%
print(df[['이름', '성별']])
# Out:
#     이름 성별
# 0  구이서  남
# 1  김이정  여
# 2  오지수  남
# 3  김선후  남
# 4  하진희  여
# 5  강현진  남
# 6  김진솔  남
# 7  박서준  여
# 8  김성희  남
# 9  이지서  여

# %%
print(df[0:3])
# Out:
#     반   이름 성별    국어    수학 응시여부 확인여부
# 0  A반  구이서  남  90.0  89.0   응시   확인
# 1  B반  김이정  여  78.0  45.0   응시   확인
# 2  A반  오지수  남   NaN   NaN   응시   확인

# %%
df['이름'][0:3]
# Out:
# 0    구이서
# 1    김이정
# 2    오지수
# Name: 이름, dtype: object

# %%
df[(df['국어']>=80)]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df.sort_values(by=['이름'], ascending = False, inplace = False)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 5  A반  강현진  남   NaN    NaN  NaN  NaN

# %%
df
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df['총점'] = df['국어'] + df['수학']
print(df) # 왜안되나. 결손값 있어서 안되나. 0으로 바꾸거나 아예 저런게 있는 행자체를 들어내버려야 되나
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0
